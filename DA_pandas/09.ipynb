# %%
import numpy as np
import pandas as pd
#matplotlib inline
from matplotlib import pyplot as plt

from numpy.random import randn
import matplotlib as mpl

print(mpl.matplotlib_fname())
# Out:
# C:\Users\hiro\.matplotlib\matplotlibrc

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.plot?

# %%
plt.plot(np.random.randn(30).cumsum(), "ko--")

# %%
plt.plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
data = randn(30).cumsum()

# %%
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='Default')
plt.legend(loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum())

ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %%
plt.plot(randn(1000).cumsum())
plt.title("aaa")
plt.xticks([0, 250, 500, 750, 1000], ['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize='small')
# Out:
# ([<matplotlib.axis.XTick at 0x20951ac2a20>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
fig, ax = plt.subplots(1, 1)  # 一番汎用性あり
ax.plot(randn(1000).cumsum())

ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=30, fontsize="large")
ax.set_title("My plot", color="coral")
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 4))

ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
ax.legend(loc='best')

# %%
import matplotlib as mpl

print(mpl.matplotlib_fname())
# Out:
# C:\Users\hiro\.matplotlib\matplotlibrc

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\hiro\\.matplotlib\\matplotlibrc'

# %%
fig, ax = plt.subplots(1, 1)

x = np.linspace(0, 10, 100)
y = np.sin(x)

ax.plot(x, y)

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0), columns=['A', 'B', 'C', 'D'], index=np.arange(0, 100, 10))

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000020952CC48D0>,
# ...
#       dtype=object)

# %%
fig, axes = plt.subplots(2, 1)

data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

data.plot.bar(ax=axes[0], color='k', alpha=0.7, figsize=(12, 8))
data.plot.barh(ax=axes[1], color='k', alpha=0.7, figsize=(12, 8))

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Genus</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>one</th>
#       <td>0.481863</td>
#       <td>0.500414</td>
#       <td>0.676501</td>
#       <td>0.728074</td>
#     </tr>
#     <tr>
#       <th>two</th>
#       <td>0.175961</td>
#       <td>0.741790</td>
#       <td>0.966429</td>
#       <td>0.638470</td>
#     </tr>
#     <tr>
#       <th>three</th>
#       <td>0.529154</td>
#       <td>0.438540</td>
#       <td>0.176933</td>
#       <td>0.736380</td>
#     </tr>
#     <tr>
#       <th>four</th>
#       <td>0.949675</td>
# ...

# %%
fig, ax = plt.subplots(1, 1)

df.plot.bar(ax=ax)

# %%
df.plot.barh(stacked=True)

# %%
party_counts = pd.DataFrame(np.random.rand(24).reshape(4, 6),
                            columns=pd.Index([1, 2, 3, 4, 5, 6], name='size'),
                            index=pd.Index(['Fri', 'Sat', 'Sun', 'Thur'], name='day'))
party_counts
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>size</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#     </tr>
#     <tr>
#       <th>day</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fri</th>
#       <td>0.706587</td>
#       <td>0.884159</td>
#       <td>0.822104</td>
#       <td>0.609240</td>
#       <td>0.731154</td>
#       <td>0.247921</td>
#     </tr>
#     <tr>
#       <th>Sat</th>
#       <td>0.864409</td>
#       <td>0.075921</td>
#       <td>0.987910</td>
# ...

# %%
party_counts = party_counts.loc[:, 2:5]
party_counts
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>size</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#     <tr>
#       <th>day</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fri</th>
#       <td>0.884159</td>
#       <td>0.822104</td>
#       <td>0.609240</td>
#       <td>0.731154</td>
#     </tr>
#     <tr>
#       <th>Sat</th>
#       <td>0.075921</td>
#       <td>0.987910</td>
#       <td>0.964942</td>
#       <td>0.222607</td>
#     </tr>
#     <tr>
#       <th>Sun</th>
#       <td>0.016851</td>
#       <td>0.699378</td>
# ...

# %%
party_pcts = party_counts.div(party_counts.sum(1), axis=0)
party_pcts
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>size</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#     </tr>
#     <tr>
#       <th>day</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fri</th>
#       <td>0.290206</td>
#       <td>0.269838</td>
#       <td>0.199970</td>
#       <td>0.239986</td>
#     </tr>
#     <tr>
#       <th>Sat</th>
#       <td>0.033722</td>
#       <td>0.438802</td>
#       <td>0.428600</td>
#       <td>0.098876</td>
#     </tr>
#     <tr>
#       <th>Sun</th>
#       <td>0.008942</td>
#       <td>0.371112</td>
# ...

# %%
party_pcts.plot.bar()

# %%
import seaborn as sns

sns.barplot(x=2, y=4, data=party_pcts, orient='h')

# %%
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values, bins=100, color='k')

# %%
data = pd.DataFrame(np.random.rand(800).reshape(200, 4),
                    columns=['cpi', 'm1', 'tbilrate', 'unemp'])
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cpi</th>
#       <th>m1</th>
#       <th>tbilrate</th>
#       <th>unemp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.180919</td>
#       <td>0.487201</td>
#       <td>0.901999</td>
#       <td>0.129666</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.486139</td>
#       <td>0.528889</td>
#       <td>0.480000</td>
#       <td>0.668711</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.886729</td>
#       <td>0.733748</td>
#       <td>0.417579</td>
#       <td>0.509030</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.834483</td>
# ...

# %%
sns.regplot(x='m1', y='unemp', data=data)

# %%
sns.pairplot(data, diag_kind='kde', plot_kws={'alpha': 0.2})
